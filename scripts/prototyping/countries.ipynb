# %%
import pandas as pd

# %%
data = pd.read_csv('data/countries_continents_codes_flags_url.csv')
df = pd.DataFrame(data)
# df

# %%
df['internet_tld'] = df['country_code'].str.lower()
# df

# %%
df['internet_tld'] = '.' + df['internet_tld']
df.dropna(inplace=True)
df

# %%
df.to_csv('data/working_dataset.csv', index=False)

# %%
df = pd.read_csv('data/working_dataset.csv')
df
# Out:
#                                  name country_code    region internet_tld  \
# 0                         Afghanistan           AF      Asia          .af
# 1                             Albania           AL    Europe          .al
# 2                             Algeria           DZ    Africa          .dz
# 3                             Andorra           AD    Europe          .ad
# 4                              Angola           AO    Africa          .ao
# ..                                ...          ...       ...          ...
# 194           Cocos (Keeling) Islands           CC   Oceania          .cc
# 195                 Republic of Congo           CG    Africa          .cg
# 196  Democratic Republic Of The Congo           CD    Africa          .cd
# 197                       Ivory Coast           CI    Africa          .ci
# 198                           Curacao           CW  Americas          .cw
#
#     calling_code                     official_name
# ...
